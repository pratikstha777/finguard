# %%
# bootstrap_servers = 'pkc-xrnwx.asia-south2.gcp.confluent.cloud:9092'
# api_key = '77B7AA6WL3TV36D4'
# api_secret = 'cfltPmcz9I+xMtss3urR7v1msZI41qYHRAtqjEv/LLy/w37WzSkIU+BnFqFkr1wQ'
# topic = 'credit_card_transaction'

# %%
import json
kafka_connection_json = dbutils.secrets.get(scope="finguard-scope", key="kafka_connection_details")
kafka_config = json.loads(kafka_connection_json)
bootstrap_servers = kafka_config['bootstrap_servers']
api_key = kafka_config['api_key']
api_secret = kafka_config['api_secret']
topic = kafka_config['topic']

# %%
jass_config = f'kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{api_key}" password="{api_secret}";'

# %%
sample_batch = (
    spark.read.format("kafka")
    .option("kafka.bootstrap.servers", bootstrap_servers)
    .option("subscribe", topic)
    .option("kafka.security.protocol", "SASL_SSL")
    .option("kafka.sasl.mechanism", "PLAIN")
    .option("kafka.sasl.jaas.config", jass_config)
    .option("startingOffsets", "earliest")
    .load()
)

# %%
sample_batch.count()
# Out:
# 67

# %%
display(sample_batch)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th></tr></thead><tbody><tr><td>VFhOODg5Nzg4</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>0</td><td>2026-08-09T10:38:12.450Z</td><td>0</td></tr><tr><td>VFhOOTUyOTk5</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>1</td><td>2026-08-09T10:38:13.859Z</td><td>0</td></tr><tr><td>VFhOMjU4Mzg5</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>2</td><td>2026-08-09T10:38:14.060Z</td><td>0</td></tr><tr><td>VFhOODk3MDYy</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>3</td><td>2026-08-09T10:38:14.461Z</td><td>0</td></tr><tr><td>VFhONTU0NTgx</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>4</td><td>2026-08-09T10:38:15.065Z</td><td>0</td></tr><tr><td>VFhOOTQ5NDQ0</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>5</td><td>2026-08-09T10:38:16.070Z</td><td>0</td></tr><tr><td>VFhONDQ3Njg4</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>6</td><td>2026-08-09T15:43:20.805Z</td><td>0</td></tr><tr><td>VFhOMTY1NTcx</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>7</td><td>2026-08-09T15:43:24.625Z</td><td>0</td></tr><tr><td>VFhOMTAxMjY2</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>8</td><td>2026-08-09T15:43:25.227Z</td><td>0</td></tr><tr><td>VFhOMzIxMTkw</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>9</td><td>2026-08-09T15:43:25.629Z</td><td>0</td></tr><tr><td>VFhOOTAxMTY3</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>10</td><td>2026-08-09T15:43:26.836Z</td><td>0</td></tr><tr><td>VFhOMzM3ODQy</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>11</td><td>2026-08-09T15:43:27.239Z</td><td>0</td></tr><tr><td>VFhOMTMwNTM5</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>12</td><td>2026-08-09T15:43:27.842Z</td><td>0</td></tr><tr><td>VFhONjE4MTIy</td><td>...</td><td>credit_card_transaction</td><td>1</td><td>13</td><td>2026-08-09T15:43:28.244Z</td><td>0</td></tr><tr><td>VFhOODI4Mzcw</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>0</td><td>2026-08-09T10:38:11.041Z</td><td>0</td></tr><tr><td>VFhOMzYyODQ1</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>1</td><td>2026-08-09T10:38:11.444Z</td><td>0</td></tr><tr><td>VFhONTE4ODM1</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>2</td><td>2026-08-09T10:38:11.644Z</td><td>0</td></tr><tr><td>VFhONzUyNzU1</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>3</td><td>2026-08-09T10:38:11.846Z</td><td>0</td></tr><tr><td>VFhOMTIwNTk0</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>4</td><td>2026-08-09T10:38:15.266Z</td><td>0</td></tr><tr><td>VFhOMjczMTc2</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>5</td><td>2026-08-09T15:43:20.202Z</td><td>0</td></tr><tr><td>VFhOOTIyNTA4</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>6</td><td>2026-08-09T15:43:21.206Z</td><td>0</td></tr><tr><td>VFhOODEwMjc4</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>7</td><td>2026-08-09T15:43:22.010Z</td><td>0</td></tr><tr><td>VFhOODI2MDky</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>8</td><td>2026-08-09T15:43:22.411Z</td><td>0</td></tr><tr><td>VFhOODUxNTEw</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>9</td><td>2026-08-09T15:43:22.814Z</td><td>0</td></tr><tr><td>VFhOOTg2MTU3</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>10</td><td>2026-08-09T15:43:23.820Z</td><td>0</td></tr><tr><td>VFhOMzE4Mjg2</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>11</td><td>2026-08-09T15:43:24.826Z</td><td>0</td></tr><tr><td>VFhOMzIyNjUw</td><td>...</td><td>credit_card_transaction</td><td>2</td><td>12</td><td>2026-08-09T15:43:27.037Z</td><td>0</td></tr><tr><td>VFhONzA0MzE3</td><td>...</td><td>credi ...

# %%
from pyspark.sql.functions import col
parsed_batch = sample_batch.select(
    col("key").cast("string"),
    col("value").cast("string"),
    col("topic"),
    col("partition"),
    col("offset"),
    col("timestamp"),
    col("timestampType")
)
display(parsed_batch)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th></tr></thead><tbody><tr><td>TXN889788</td><td>{"transaction_id": "TXN889788", "customer_id": "CUST000345", "card_number": "4495528938911901", "merchant_id": "MER0043", "merchant_name": "HealthFirst 43", "merchant_category": "Pharmacy", "amount": 76978.6, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "MOBILE_APP", "device_id": "DEV6635", "city": "Jaipur", "country": "India", "transaction_timestamp": "2026-08-09T10:38:12Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>0</td><td>2026-08-09T10:38:12.450Z</td><td>0</td></tr><tr><td>TXN952999</td><td>{"transaction_id": "TXN952999", "customer_id": "CUST000547", "card_number": "4614878245569640", "merchant_id": "MER0095", "merchant_name": "TripVista 95", "merchant_category": "Travel", "amount": 69114.55, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "POS", "device_id": "DEV0547", "city": "Jaipur", "country": "India", "transaction_timestamp": "2026-08-09T10:38:13Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>1</td><td>2026-08-09T10:38:13.859Z</td><td>0</td></tr><tr><td>TXN258389</td><td>{"transaction_id": "TXN258389", "customer_id": "CUST000277", "card_number": "4827718129826656", "merchant_id": "MER0086", "merchant_name": "Spice Avenue 86", "merchant_category": "Restaurant", "amount": 91857.95, "currency": "INR", "transaction_type": "ONLINE", "payment_channel": "POS", "device_id": "DEV0277", "city": "Chennai", "country": "India", "transaction_timestamp": "2026-08-09T10:38:14Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>2</td><td>2026-08-09T10:38:14.060Z</td><td>0</td></tr><tr><td>TXN897062</td><td>{"transaction_id": "TXN897062", "customer_id": "CUST000218", "card_number": "5110809969308484", "merchant_id": "MER0192", "merchant_name": "Grocer Go 192", "merchant_category": "Grocery", "amount": 68975.68, "currency": "INR", "transaction_type": "ONLINE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0218", "city": "Lucknow", "country": "India", "transaction_timestamp": "2026-08-09T10:38:14Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>3</td><td>2026-08-09T10:38:14.461Z</td><td>0</td></tr><tr><td>TXN554581</td><td>{"transaction_id": "TXN554581", "customer_id": "CUST000774", "card_number": "5808806220722393", "merchant_id": "MER0017", "merchant_name": "Diamond Lane 17", "merchant_category": "Jewellery", "amount": 45747.37, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "POS", "device_id": "DEV0774", "city": "Mumbai", "country": "India", "transaction_timestamp": "2026-08-09T10:38:15Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>4</td><td>2026-08-09T10:38:15.065Z</td><td>0</td></tr><tr><td>TXN949444</td><td>{"transaction_id": "TXN949444", "customer_id": "CUST000996", "card_number": "4233222801944256", "merchant_id": "MER0194", "merchant_name": "Tasty Table 194", "merchant_category": "Restaurant", "amount": 70405.22, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0996", "city": "Mumbai", "country": "India", "transaction_timestamp": "2026-08-09T10:38:16Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>5</td><td>2026-08-09T10:38:16.070Z</td><td>0</td></tr><tr><td>TXN447688</td><td>{"transaction_id": "TXN447688", "customer_id": "CUST000239", "card_number": "5729293143866328", "merchant_id": "MER0194", "merchant_name": "Tasty Table 194", "merchant_category": "Restaurant", "amount": 82490.2, "currency": "INR", " ...

# %%
parsed_batch.write.saveAsTable("finguard.bronze.transaction_batch_test")

# %%
streaming_df = (
    spark.readStream.format("kafka")
    .option("kafka.bootstrap.servers", bootstrap_servers)
    .option("subscribe", topic)
    .option("kafka.security.protocol", "SASL_SSL")
    .option("kafka.sasl.mechanism", "PLAIN")
    .option("kafka.sasl.jaas.config", jass_config)
    .option("startingOffsets", "earliest")
    .load()
)

# %%
from pyspark.sql.functions import col
parsed_streaming_df = streaming_df.select(
    col("key").cast("string"),
    col("value").cast("string"),
    col("topic"),
    col("partition"),
    col("offset"),
    col("timestamp"),
    col("timestampType")
)

# %%
streaming_query = (parsed_streaming_df.writeStream.format("delta")
.outputMode("Append")
.option("checkpointLocation", "/Volumes/finguard/source/transactions/checkpoint/")
.trigger(availableNow= True)
.toTable("finguard.bronze.transaction_streaming_test")
)
print("Query Started with query id:", streaming_query.id)
# Out:
# Query Started with query id: d111f23f-17f4-4f51-9285-58f0c11deadf

# %%
# %sql
select * from finguard.bronze.transaction_streaming_test;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th></tr></thead><tbody><tr><td>TXN889788</td><td>{"transaction_id": "TXN889788", "customer_id": "CUST000345", "card_number": "4495528938911901", "merchant_id": "MER0043", "merchant_name": "HealthFirst 43", "merchant_category": "Pharmacy", "amount": 76978.6, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "MOBILE_APP", "device_id": "DEV6635", "city": "Jaipur", "country": "India", "transaction_timestamp": "2026-08-09T10:38:12Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>0</td><td>2026-08-09T10:38:12.450Z</td><td>0</td></tr><tr><td>TXN952999</td><td>{"transaction_id": "TXN952999", "customer_id": "CUST000547", "card_number": "4614878245569640", "merchant_id": "MER0095", "merchant_name": "TripVista 95", "merchant_category": "Travel", "amount": 69114.55, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "POS", "device_id": "DEV0547", "city": "Jaipur", "country": "India", "transaction_timestamp": "2026-08-09T10:38:13Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>1</td><td>2026-08-09T10:38:13.859Z</td><td>0</td></tr><tr><td>TXN258389</td><td>{"transaction_id": "TXN258389", "customer_id": "CUST000277", "card_number": "4827718129826656", "merchant_id": "MER0086", "merchant_name": "Spice Avenue 86", "merchant_category": "Restaurant", "amount": 91857.95, "currency": "INR", "transaction_type": "ONLINE", "payment_channel": "POS", "device_id": "DEV0277", "city": "Chennai", "country": "India", "transaction_timestamp": "2026-08-09T10:38:14Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>2</td><td>2026-08-09T10:38:14.060Z</td><td>0</td></tr><tr><td>TXN897062</td><td>{"transaction_id": "TXN897062", "customer_id": "CUST000218", "card_number": "5110809969308484", "merchant_id": "MER0192", "merchant_name": "Grocer Go 192", "merchant_category": "Grocery", "amount": 68975.68, "currency": "INR", "transaction_type": "ONLINE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0218", "city": "Lucknow", "country": "India", "transaction_timestamp": "2026-08-09T10:38:14Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>3</td><td>2026-08-09T10:38:14.461Z</td><td>0</td></tr><tr><td>TXN554581</td><td>{"transaction_id": "TXN554581", "customer_id": "CUST000774", "card_number": "5808806220722393", "merchant_id": "MER0017", "merchant_name": "Diamond Lane 17", "merchant_category": "Jewellery", "amount": 45747.37, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "POS", "device_id": "DEV0774", "city": "Mumbai", "country": "India", "transaction_timestamp": "2026-08-09T10:38:15Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>4</td><td>2026-08-09T10:38:15.065Z</td><td>0</td></tr><tr><td>TXN949444</td><td>{"transaction_id": "TXN949444", "customer_id": "CUST000996", "card_number": "4233222801944256", "merchant_id": "MER0194", "merchant_name": "Tasty Table 194", "merchant_category": "Restaurant", "amount": 70405.22, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0996", "city": "Mumbai", "country": "India", "transaction_timestamp": "2026-08-09T10:38:16Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transaction</td><td>1</td><td>5</td><td>2026-08-09T10:38:16.070Z</td><td>0</td></tr><tr><td>TXN447688</td><td>{"transaction_id": "TXN447688", "customer_id": "CUST000239", "card_number": "5729293143866328", "merchant_id": "MER0194", "merchant_name": "Tasty Table 194", "merchant_category": "Restaurant", "amount": 82490.2, "currency": "INR", " ...

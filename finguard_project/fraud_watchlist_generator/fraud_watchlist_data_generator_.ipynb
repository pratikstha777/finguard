# %%
# Databricks notebook source
# DBTITLE 1,Generate fraud watchlist JSON files from CSV
import pandas as pd
import json
import time
from datetime import datetime
import os

# Read the CSV file from the same folder
csv_path = "/Workspace/Users/pratikstha278@gmail.com/finguard_project/fraud_watchlist_generator/fraud_watchlist.csv"
df = pd.read_csv(csv_path)

# Ensure entity_id is always a string for JSON serialization
df['entity_id'] = df['entity_id'].astype(str)

# Target volume path
output_path = "/Volumes/finguard/source/fraud_watchlist/source_data/"

# Ensure the output directory exists
dbutils.fs.mkdirs(output_path)

# Check for existing files and find the latest watchlist_id
latest_watchlist_id = None
try:
    existing_files = dbutils.fs.ls(output_path)
    if existing_files:
        print(f"Found {len(existing_files)} existing files in {output_path}")
        print("Scanning for latest watchlist_id...")
        
        max_id_num = 0
        for file_info in existing_files:
            if file_info.name.endswith('.json'):
                try:
                    # Read the JSON file
                    content = dbutils.fs.head(file_info.path, 10000)
                    data = json.loads(content)
                    watchlist_id = data.get('watchlist_id', '')
                    # Extract numeric part from watchlist_id (e.g., "WL000001" -> 1)
                    if watchlist_id.startswith('WL'):
                        id_num = int(watchlist_id[2:])
                        if id_num > max_id_num:
                            max_id_num = id_num
                            latest_watchlist_id = watchlist_id
                except Exception as e:
                    continue
        
        if latest_watchlist_id:
            print(f"Latest watchlist_id found: {latest_watchlist_id} (numeric: {max_id_num})")
            # Filter dataframe to start from next record using numeric comparison
            # Extract numeric part from dataframe's watchlist_id for comparison
            df['_id_num'] = df['watchlist_id'].str[2:].astype(int)
            df = df[df['_id_num'] > max_id_num].drop(columns=['_id_num']).reset_index(drop=True)
            print(f"Resuming from next record. {len(df)} rows remaining to process.\n")
        else:
            print("No valid watchlist_id found in existing files. Starting from beginning.\n")
    else:
        print("No existing files found. Starting from beginning.\n")
except Exception as e:
    print(f"Could not read existing files: {e}")
    print("Starting from beginning.\n")

if len(df) == 0:
    print("All records have already been processed!")
else:
    print(f"Starting to process {len(df)} rows from fraud_watchlist.csv")
    print(f"Writing JSON files to: {output_path}")
    print("\n" + "="*60 + "\n")

    # Process each row one at a time
    for index, row in df.iterrows():
        # Convert row to dictionary (column name as key, column value as value)
        row_dict = row.to_dict()
        
        # Ensure entity_id is a string in the dictionary
        row_dict['entity_id'] = str(row_dict['entity_id'])
        
        # Print the entire row being written
        print(f"Entire row being written: {row_dict}")
        
        # Create a unique filename with timestamp
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
        filename = f"fraud_watchlist_{timestamp}_{index}.json"
        file_path = f"{output_path}/{filename}"
        
        # Write JSON to file using dbutils.fs (required for Unity Catalog volumes)
        # Single-line JSON format
        json_content = json.dumps(row_dict)
        dbutils.fs.put(file_path, json_content, overwrite=True)
        
        print(f"Row {index + 1}/{len(df)}: Written {filename}")
        print(f"  Watchlist ID: {row_dict.get('watchlist_id')}")
        
        # Wait 5 seconds before processing next row (except for the last one)
        if index < len(df) - 1:
            print(f"  Waiting 5 seconds...\n")
            time.sleep(5)
    
    print("\n" + "="*60)
    print(f"\nCompleted! Generated {len(df)} JSON files in {output_path}")
# Out:
# Found 5 existing files in /Volumes/finguard/source/fraud_watchlist/source_data/
# Scanning for latest watchlist_id...
# No valid watchlist_id found in existing files. Starting from beginning.
#
# Starting to process 341 rows from fraud_watchlist.csv
# Writing JSON files to: /Volumes/finguard/source/fraud_watchlist/source_data/
#
# ============================================================
#
# Entire row being written: {'watchlist_id': 'wl000001', 'watch_type': 'CARD', 'entity_id': '5008514036965665', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:00:00', 'reported_by': 'SOC', 'reported_source': 'Manual', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 365 bytes.
# Row 1/341: Written fraud_watchlist_20260814_141652_636169_0.json
#   Watchlist ID: wl000001
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000002', 'watch_type': 'CARD', 'entity_id': '4413337312552355', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:01:00', 'reported_by': 'SOC', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Pune'}
# Wrote 379 bytes.
# Row 2/341: Written fraud_watchlist_20260814_141658_184072_1.json
#   Watchlist ID: wl000002
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000003', 'watch_type': 'CARD', 'entity_id': '5329839542961842', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:02:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Delhi'}
# Wrote 380 bytes.
# Row 3/341: Written fraud_watchlist_20260814_141703_653713_2.json
#   Watchlist ID: wl000003
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000004', 'watch_type': 'CARD', 'entity_id': '4717327980595032', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:04:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Chennai'}
# Wrote 383 bytes.
# Row 4/341: Written fraud_watchlist_20260814_141709_056277_3.json
#   Watchlist ID: wl000004
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000005', 'watch_type': 'CARD', 'entity_id': '4260650191792026', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:07:00', 'reported_by': 'Customer Care', 'reported_source': 'CRM', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 384 bytes.
# Row 5/341: Written fraud_watchlist_20260814_141714_552827_4.json
#   Watchlist ID: wl000005
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000006', 'watch_type': 'CARD', 'entity_id': '4009109391119268', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:12:00', 'reported_by': 'SOC', 'reported_source': 'Manual', 'country': 'India', 'city': 'Mumbai'}
# Wrote 370 bytes.
# Row 6/341: Written fraud_watchlist_20260814_141719_943890_5.json
#   Watchlist ID: wl000006
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000007', 'watch_type': 'CARD', 'entity_id': '5953506373118040', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:28:00', 'reported_by': 'AML Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Chennai'}
# Wrote 378 bytes.
# Row 7/341: Written fraud_watchlist_20260814_141725_414628_6.json
#   Watchlist ID: wl000007
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000008', 'watch_type': 'CARD', 'entity_id': '4519832731585146', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:31:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 389 bytes.
# Row 8/341: Written fraud_watchlist_20260814_141730_816807_7.json
#   Watchlist ID: wl000008
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000009', 'watch_type': 'CARD', 'entity_id': '4910622723626693', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'VELOCITY_FRAUD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:32:00', 'reported_by': 'AML Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Chennai'}
# Wrote 374 bytes.
# Row 9/341: Written fraud_watchlist_20260814_141736_315335_8.json
#   Watchlist ID: wl000009
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000010', 'watch_type': 'CARD', 'entity_id': '5229812099576576', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:33:00', 'reported_by': 'Customer Care', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Mumbai'}
# Wrote 379 bytes.
# Row 10/341: Written fraud_watchlist_20260814_141741_678114_9.json
#   Watchlist ID: wl000010
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000011', 'watch_type': 'CARD', 'entity_id': '5310720113798442', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'LOST_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:35:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 363 bytes.
# Row 11/341: Written fraud_watchlist_20260814_141747_136641_10.json
#   Watchlist ID: wl000011
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000012', 'watch_type': 'CARD', 'entity_id': '5456232858842477', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'MONEY_LAUNDERING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:37:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Mumbai'}
# Wrote 374 bytes.
# Row 12/341: Written fraud_watchlist_20260814_141752_535234_11.json
#   Watchlist ID: wl000012
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000013', 'watch_type': 'CARD', 'entity_id': '5791776334272032', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'LOST_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:41:00', 'reported_by': 'Customer Care', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Mumbai'}
# Wrote 382 bytes.
# Row 13/341: Written fraud_watchlist_20260814_141758_019651_12.json
#   Watchlist ID: wl000013
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000014', 'watch_type': 'CARD', 'entity_id': '5863144170646255', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:43:00', 'reported_by': 'Fraud Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Pune'}
# Wrote 377 bytes.
# Row 14/341: Written fraud_watchlist_20260814_141803_445833_13.json
#   Watchlist ID: wl000014
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000015', 'watch_type': 'CARD', 'entity_id': '5729293143866328', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:49:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Delhi'}
# Wrote 361 bytes.
# Row 15/341: Written fraud_watchlist_20260814_141809_005522_14.json
#   Watchlist ID: wl000015
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000016', 'watch_type': 'CARD', 'entity_id': '4552457871584155', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:53:00', 'reported_by': 'SOC', 'reported_source': 'Manual', 'country': 'India', 'city': 'Mumbai'}
# Wrote 373 bytes.
# Row 16/341: Written fraud_watchlist_20260814_141814_409070_15.json
#   Watchlist ID: wl000016
#   Waiting 5 seconds...
